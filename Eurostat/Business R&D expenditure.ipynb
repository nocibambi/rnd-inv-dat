# %% [markdown]
# # Importing the libraries

# %%
from pandasdmx import Request

# %%
import pandas as pd

# %%
from bokeh.io import output_notebook, show
from bokeh.plotting import figure

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="618820ed-c7e3-4f17-b485-af0ba8544f8c">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# # Connecting to the webservice

# %%
estat = Request('ESTAT')

# %% [markdown]
# ### Downloading dataflow definitions

# %%
dflow = estat.dataflow()

# %% [markdown]
# ## Defining functions

# %% [markdown]
# ### Data structure

# %%
def dsd_resp(id):
    """
    The function takes a dataflow identifier and requests from the Eurostat SDMX api the dataflow's datastructure, datastructure id and datastructure response.
    """    
    # Defining the data set's dataflow based on the data set id.
    df = dflow.dataflow[id]
    
    # Printing the table's name
    print("The table's name:")
    print(dflow.write().dataflow.loc[id][0])
    
    # Acquiring the dataflow's datastructure id
    dsd_id = df.structure.id
    
    # Requesting for the dataflow's datastructure
    dsd_resp = estat.get(resource_type = 'datastructure', resource_id = dsd_id)
    
    # Requesting the dataflow's datastructure
    dsd = dsd_resp.datastructure[dsd_id]
    
    return dsd_resp, dsd_id, dsd

# %% [markdown]
# ### Datastructure attributes

# %%
def dsd_att(dsd):
    """The function takes a table datastructure definition and prints its measure, dimension and attribute lists."""
    # Measures
    print("Measures:")
    print(dsd.measures.aslist())
    
    # Dimensions
    print("\nDimensions:")
    print(dsd.dimensions.aslist())
    
    # Attributes
    print("\nAttributes:")
    print(dsd.attributes.aslist())

# %% [markdown]
# ## Selecting the tables

# %% [markdown]
# ### Listing the tables from the 'High-tech industry and knowledge-intensive services (**htec**)' database

# %%
dflow.write().dataflow[dflow.write().dataflow.index.str.startswith('htec') == True]
# Out:
#                                                                name
# dataflow
# htec_cis3         Innovation in high-tech sectors in SMEs (CIS3)...
# htec_cis4         Innovation in high-tech sectors (CIS 2004), EU...
# htec_cis5         Innovation in high-tech sectors (CIS 2006), EU...
# htec_cis6         Innovation in high-tech sectors (CIS 2008, CIS...
# htec_eco_ent      Enterprises in high-tech sectors by NACE Rev.1...
# htec_eco_ent2     Enterprises in high-tech sectors by NACE Rev.2...
# htec_eco_sbs      Economic data in high-tech sectors by NACE Rev...
# htec_eco_sbs2     Economic data in high-tech sectors by NACE Rev...
# htec_emp_nat      Employment in technology and knowledge-intensi...
# htec_emp_nat2     Employment in technology and knowledge-intensi...
# htec_emp_nisced   Employment in technology and knowledge-intensi...
# htec_emp_nisced2  Employment in technology and knowledge-intensi...
# htec_emp_nisco    Employment in technology and knowledge-intensi...
# htec_emp_nisco2   Employment in technology and knowledge-intensi...
# htec_emp_reg      Employment in technology and knowledge-intensi...
# htec_emp_reg2     Employment in technology and knowledge-intensi...
# htec_emp_risced   Employment in technology and knowledge-intensi...
# htec_emp_risced2  Employment in technology and knowledge-intensi...
# htec_emp_risco    Employment in technology and knowledge-intensi...
# htec_emp_risco2   Employment in technology and knowledge-intensi...
# htec_emp_sbs      Employment statistics on high-tech industries ...
# htec_emp_sbs2     Employment statistics on high-tech industries ...
# htec_kia_emp      Annual data on employment in knowledge-intensi...
# htec_kia_emp2     Annual data on employment in knowledge-intensi...
# htec_si_exp4      High-tech exports - Exports of high technology...
# htec_sti_exp      Business enterprise R&D expenditure in high-te...
# htec_sti_exp2     Business enterprise R&D expenditure in high-te...
# htec_sti_pers     Business enterprise R&D personnel in high-tech...
# htec_sti_pers2    Business enterprise R&D personnel in high-tech...
# htec_trd_group4   High-tech trade by high-tech group of products...
# htec_trd_tot4     Total high-tech trade in million euro and as a...
# htec_vci_stage1   Venture capital investment by aggregated stage...
# htec_vci_stage2   Venture capital investment by detailed stage o...

# %% [markdown]
# ### The tables I am going to analyze

# %%
id1 = 'htec_sti_exp2'

# %%
dflow.write().dataflow.loc[id1][0]
# Out:
# 'Business enterprise R&D expenditure in high-tech sectors - NACE Rev. 2'

# %%
id2 = 'htec_vci_stage2'

# %%
dflow.write().dataflow.loc[id2][0]
# Out:
# 'Venture capital investment by detailed stage of development (from 2007, source: EVCA)'

# %% [markdown]
# # Business R&D expenditure

# %% [markdown]
# ### Getting the table's dataflow definition and datastructure

# %%
dsd_resp1, dsd_id1, dsd1 = dsd_resp(id1)
# Out:
# The table's name:
# Business enterprise R&D expenditure in high-tech sectors - NACE Rev. 2

# %% [markdown]
# ### Datastructure measures, dimensions, attributes and codelist

# %%
dsd_att(dsd1)
# Out:
# Measures:
# [PrimaryMeasure | OBS_VALUE]
#
# Dimensions:
# [Dimension | FREQ, Dimension | UNIT, Dimension | NACE_R2, Dimension | GEO, TimeDimension | TIME_PERIOD]
#
# Attributes:
# [DataAttribute | OBS_FLAG, DataAttribute | OBS_STATUS]

# %% [markdown]
# Codelist:

# %%
dsd_resp1.write().codelist
# Out:
#                       dim_or_attr  \
# FREQ       FREQ                 D
#            A                    D
#            D                    D
#            H                    D
#            M                    D
#            Q                    D
#            S                    D
#            W                    D
# UNIT       UNIT                 D
#            MIO_EUR              D
# NACE_R2    NACE_R2              D
#            C                    D
#            C_HTC                D
#            C_HTC_M              D
#            C_LTC                D
#            C_LTC_M              D
#            G-N                  D
#            TOTAL                D
# GEO        GEO                  D
#            AT                   D
#            BE                   D
#            BG                   D
#            CH                   D
#            CN_X_HK              D
#            CY                   D
#            CZ                   D
#            DE                   D
#            DK                   D
#            EE                   D
#            EL                   D
# ...                           ...
#            NL                   D
#            NO                   D
#            PL                   D
#            PT                   D
#            RO                   D
#            RS                   D
#            RU                   D
#            SE                   D
#            SI                   D
#            SK                   D
#            TR                   D
#            UK                   D
#            US                   D
# OBS_FLAG   OBS_FLAG             A
#            b                    A
#            c                    A
#            d                    A
#            e                    A
#            f                    A
#            i                    A
#            n                    A
#            p                    A
#            r                    A
#            s                    A
#            u                    A
#            z                    A
# OBS_STATUS OBS_STATUS           A
#            -                    A
#            0                    A
#            na                   A
#
#                                                                    name
# FREQ       FREQ                                                    FREQ
#            A                                                     Annual
#            D                                                      Daily
#            H                                                  Half-year
#            M                                                    Monthly
#            Q                                                  Quarterly
#            S                                                Semi-annual
#            W                                                     Weekly
# UNIT       UNIT                                                    UNIT
#            MIO_EUR                                         Million euro
# NACE_R2    NACE_R2                                              NACE_R2
#            C                                              Manufacturing
#            C_HTC                          High-technology manufacturing
#            C_HTC_M                 Medium high-technology manufacturing
#            C_LTC                           Low-technology manufacturing
#            C_LTC_M                  Medium low-technology manufacturing
#            G-N                         Services of the business economy
#            TOTAL                            Total - all NACE activities
# GEO        GEO                                                      GEO
#            AT                                                   Austria
#            BE                                                   Belgium
#            BG                                                  Bulgaria
#            CH                                               Switzerland
#            CN_X_HK                               China except Hong Kong
#            CY                                                    Cyprus
#            CZ                                            Czech Republic
#            DE          Germany (until 1990 former territory of the FRG)
#            DK                                                   Denmark
#            EE                                                   Estonia
#            EL                                                    Greece
# ...                                                                 ...
#            NL                                               Netherlands
#            NO                                                    Norway
#            PL                                                    Poland
#            PT                                                  Portugal
#            RO                                                   Romania
#            RS                                                    Serbia
#            RU                                                    Russia
#            SE                                                    Sweden
#            SI                                                  Slovenia
#            SK                                                  Slovakia
#            TR                                                    Turkey
#            UK                                            United Kingdom
#            US                                             United States
# OBS_FLAG   OBS_FLAG                                   Observation flag.
#            b                                       break in time series
#            c                                               confidential
#            d                           definition differs, see metadata
#            e                                                  estimated
#            f                                                   forecast
#            i                                  see metadata (phased out)
#            n                                            not significant
#            p                                                provisional
#            r                                                    revised
#            s                             Eurostat estimate (phased out)
#            u                                            low reliability
#            z                                             not applicable
# OBS_STATUS OBS_STATUS                               Observation status.
#            -             not applicable or real zero or zero by default
#            0                            less than half of the unit used
#            na                                             not available
#
# [76 rows x 2 columns]

# %% [markdown]
# ### Requesting the data

# %%
dresp1 = estat.get(resource_type = 'data',
                   resource_id = id1,
                   params = {'references': None,
                             'startPeriod': '2014',
                             'endPeriod': '2014'
                            })

# %%
dat1 = dresp1.data

# %%
dat1.dim_at_obs
# Out:
# 'TIME_PERIOD'

# %%
ser1 = list(dat1.series)
len(ser1)
# Out:
# 280

# %%
ser1[5].key
# Out:
# SeriesKey(UNIT='MIO_EUR', NACE_R2='C', GEO='CY', FREQ='A')

# %%
set(s.key.GEO for s in dat1.series)
# Out:
# {'AT',
#  'BE',
#  'BG',
#  'CH',
#  'CN_X_HK',
#  'CY',
#  'CZ',
#  'DE',
#  'DK',
#  'EE',
#  'EL',
#  'ES',
#  'EU28',
#  'FI',
#  'FR',
#  'HR',
#  'HU',
#  'IE',
#  'IS',
#  'IT',
#  'JP',
#  'KR',
#  'LT',
#  'LU',
#  'LV',
#  'ME',
#  'MT',
#  'NL',
#  'NO',
#  'PL',
#  'PT',
#  'RO',
#  'RS',
#  'RU',
#  'SE',
#  'SI',
#  'SK',
#  'TR',
#  'UK',
#  'US'}

# %% [markdown]
# ### Writing the data into DataFrame

# %%
iter1 = (s for s in dat1.series if (s.key.GEO in ['CN_X_HK', 'EU28', 'US']) == False)
tab1 = dresp1.write(iter1)
tab1 = tab1.stack('GEO')
tab1.columns = tab1.columns.droplevel(['FREQ','UNIT']) # Dropping 'FREQ' and 'UNIT' levels
tab1 = tab1.loc['2014']
tab1.index = tab1.index.droplevel(0) # Dropping the 'TIME_PERIOD' axis
tab1.dropna(axis = 0, how = 'any', inplace = True)
tab1
# Out:
# NACE_R2        C    C_HTC  C_HTC_M   C_LTC  C_LTC_M      G-N    TOTAL
# GEO
# CY           5.0      4.0      0.0     0.0      1.0      4.0     15.0
# CZ         976.0    107.0    609.0    37.0    223.0    688.0   1730.0
# DE       49482.0  11541.0  33187.0  1343.0   3401.0   7061.0  56997.0
# DK        2814.0   1526.0    956.0   236.0     96.0   1985.0   4865.0
# ES        3096.0    748.0   1519.0   426.0    403.0   3212.0   6784.0
# FI        3126.0   1873.0    892.0   190.0    171.0   1133.0   4410.0
# HR          85.0     49.0     28.0     6.0      3.0     73.0    164.0
# HU         526.0    232.0    201.0    44.0     49.0    435.0   1022.0
# IT        8736.0   1822.0   5029.0   966.0    919.0   3163.0  12344.0
# LT          50.0     15.0     17.0    12.0      5.0     64.0    116.0
# MT          10.0      5.0      3.0     1.0      1.0     23.0     33.0
# NL        4389.0    942.0   2455.0   463.0    529.0   2627.0   7433.0
# PL         821.0    104.0    399.0   145.0    173.0    891.0   1800.0
# SI         455.0    204.0    165.0    22.0     65.0    224.0    689.0
# TR        1562.0    166.0   1064.0   117.0    216.0   1404.0   3014.0
# UK        9656.0   1745.0   6080.0   689.0   1143.0  14296.0  24730.0

# %%
p = figure(plot_width = 400, plot_height = 400)
p.circle(tab1.loc[:,'C'], tab1.loc[:,'G-N'], size = 10, color = "purple", alpha = 0.6)
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="1272152f-d9e4-434d-b15f-17c9b50f7c46"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("1272152f-d9e4-434d-b15f-17c9b50f7c46");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("1272152f-d9e4-434d-b15f-17c9b50f7c46");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '1272152f-d9e4-434d-b15f-17c9b50f7c46' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"8d0f7c1f-aa6a-4f05-b6fb-d693e8733078":{"roots":{"references":[{"attributes":{"plot":{"id":"2604203a-c6b7-42a0-a0a9-9f99029353b4","subtype":"Figure","type":"Plot"}},"id":"4520296f-3a29-4d7d-a2ef-f62e72d02d17","type":"ResetTool"},{"attributes":{"dimension":1,"plot":{"id":"2604203a-c6b7-42a0-a0a9-9f99029353b4","subtype":"Figure","type":"Plot"},"ticker":{"id":"e9e90bf5-4763-4233-a689-f6d566c9154d","type":"BasicTicker"}},"id":"2bc80af5-60f0-4016-b55f-19b37c42bd4e","type":"Grid"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"3bee4235-3751-4187-bd06-c3d52f5b7c62","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"2604203a-c6b7-42a0-a0a9-9f99029353b4","subtype":"Figure","type":"Plot"}},"id":"a68ea9f3-e168-406c-b3af-073525df3646","type":"PanTool"},{"attributes":{"formatter":{"id":"6bbe8162-7863-42ce-a510-3c72f252a0d4","type":"BasicTickFormatter"},"plot":{"id":"2604203a-c6b7-42a0-a0a9-9f99029353b4","subtype":"Figure","type":"Plot"},"ticker":{"id":"e9e90bf5-4763-4233-a689-f6d566c9154d","type":"BasicTicker"}},"id":"8078f5ca-280a-4433-9de8-ca976e263964","type":"LinearAxis"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"AAAAAAAAFEAAAAAAAICOQAAAAABAKehAAAAAAAD8pUAAAAAAADCoQAAAAAAAbKhAAAAAAABAVUAAAAAAAHCAQAAAAAAAEMFAAAAAAAAASUAAAAAAAAAkQAAAAAAAJbFAAAAAAACoiUAAAAAAAHB8QAAAAAAAaJhAAAAAAADcwkA=","dtype":"float64","shape":[16]},"y":{"__ndarray__":"AAAAAAAAEEAAAAAAAICFQAAAAAAAlbtAAAAAAAAEn0AAAAAAABipQAAAAAAAtJFAAAAAAABAUkAAAAAAADB7QAAAAAAAtqhAAAAAAAAAUEAAAAAAAAA3QAAAAAAAhqRAAAAAAADYi0AAAAAAAABsQAAAAAAA8JVAAAAAAADsy0A=","dtype":"float64","shape":[16]}}},"id":"d3cd2bfb-be02-4556-838e-34b4b291fdb2","type":"ColumnDataSource"},{"attributes":{"overlay":{"id":"3bee4235-3751-4187-bd06-c3d52f5b7c62","type":"BoxAnnotation"},"plot":{"id":"2604203a-c6b7-42a0-a0a9-9f99029353b4","subtype":"Figure","type":"Plot"}},"id":"11567fd7-af13-49c9-a18c-d1257e2dfc85","type":"BoxZoomTool"},{"attributes":{"plot":null,"text":""},"id":"a32a4b86-6a3a-403a-9950-d47718cc8898","type":"Title"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"a68ea9f3-e168-406c-b3af-073525df3646","type":"PanTool"},{"id":"15cb92a0-52a7-40fe-9aa7-31e67ba76190","type":"WheelZoomTool"},{"id":"11567fd7-af13-49c9-a18c-d1257e2dfc85","type":"BoxZoomTool"},{"id":"3349b6f3-06c4-4f57-96f3-a8cd1f60be38","type":"SaveTool"},{"id":"4520296f-3a29-4d7d-a2ef-f62e72d02d17","type":"ResetTool"},{"id":"72523aa9-bc43-44fa-b8c2-65e149f0cc90","type":"HelpTool"}]},"id":"33f37207-17df-499c-8638-4c13fc4cb867","type":"Toolbar"},{"attributes":{"formatter":{"id":"8c013166-fe88-4d08-8701-ef1fceee86b8","type":"BasicTickFormatter"},"plot":{"id":"2604203a-c6b7-42a0-a0a9-9f99029353b4","subtype":"Figure","type":"Plot"},"ticker":{"id":"614d72b4-6bd7-4dd0-95bf-91ddc97925c0","type":"BasicTicker"}},"id":"e04b4316-18e1-46b2-a716-e0e13e41d4da","type":"LinearAxis"},{"attributes":{"callback":null},"id":"65e582a1-b608-406e-9d8b-bc2d75089ecf","type":"DataRange1d"},{"attributes":{},"id":"e9e90bf5-4763-4233-a689-f6d566c9154d","type":"BasicTicker"},{"attributes":{"fill_alpha":{"value":0.6},"fill_color":{"value":"purple"},"line_alpha":{"value":0.6},"line_color":{"value":"purple"},"size":{"units":"screen","value":10},"x":{"field":"x"},"y":{"field":"y"}},"id":"b0a68864-a310-4369-ad01-d407a0bc4d4d","type":"Circle"},{"attributes":{},"id":"6bbe8162-7863-42ce-a510-3c72f252a0d4","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"2604203a-c6b7-42a0-a0a9-9f99029353b4","subtype":"Figure","type":"Plot"}},"id":"3349b6f3-06c4-4f57-96f3-a8cd1f60be38","type":"SaveTool"},{"attributes":{"plot":{"id":"2604203a-c6b7-42a0-a0a9-9f99029353b4","subtype":"Figure","type":"Plot"} ...
